# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\User\Downloads\rainfall in india 1901-2015.csv')
S=pd.unique(df['SUBDIVISION'])

# %%
St=np.array(S)
#Applying a loop for all the states present in the dataset
for i in range(np.size(St)):
    #Cleaning the data and initialising variables
    df1=df[df['SUBDIVISION']==St[i]]                #obtaining dataset of a particular state
    df1=df1.dropna()                                #dropping the null values
    L=df1['ANNUAL']
    count=0
    Y=np.array(L)
    B=df1['YEAR']
    X=np.array(B)
    m=np.size(Y)

    # Function to generate an exponential fit curve using alpha as a parameter
    def exp_smoothing(x,y,alpha):
        m=np.size(x)
        y_pred=np.zeros(m)
        y_pred[0]=y[0]
        for i in range(1,m):
            y_pred[i]=alpha*x[i]+(1-alpha)*y[i-1]
        return y_pred

    # Extending the above curve to predict value for the given year
    def exp_smoothing_extn(x,y,year,alpha):
        m=np.size(x)
        X=[i for i in range(2016,(year+1))]
        X=np.array(X)
        X=np.concatenate((x,X))
        y_pred=np.zeros(np.size(X))
        y_pred[0:m]=exp_smoothing(x,y,alpha)
        for i in range(m,np.size(y_pred)):
            y_pred[i]=alpha*X[i]+(1-alpha)*y_pred[i-1]
        return y_pred
    # RMS Error for the obtained curve
    def exp_smooth_error(x,y,alpha):
        n=np.size(y)
        y_pred=exp_smoothing(x,y,alpha)
        err=(np.sum((y_pred-y)**2)/np.size(y))**(0.5)
        return err
    #Finding alpha with minimum rms error
    def find_alpha(x,y):
        dict={exp_smooth_error(x,y,alpha):alpha for alpha in np.arange(0.0,1.0,0.01)}
        L=[exp_smooth_error(x,y,alpha) for alpha in np.arange(0.0,1.0,0.01)]
        x=min(L)
        return dict[x]
    alpha=find_alpha(X,Y)


    #Finding the rolling mean
    mean=np.zeros(m)
    mean[0]=Y[0]
    for j in range(m):
        count=count+Y[j]
        mean[j]=count/(j+1)
    err=(np.sum((mean-Y)**2))/m
    print('Training set error for moving average ' + St[i]+ '  %f' %((err)**0.5))
    print('Training set error for exponential smothing ' + St[i]+ '  %f' %((exp_smooth_error(X,Y,alpha))))

    #Predictions for the year 2021
    x1=2021
    si=x1-2015
    In_pre=np.zeros(si)
    In_pre[0]=mean[j]
    for l in range(1,si):
        count=count+In_pre[l-1]
        In_pre[l]=count/(j+l+1)
    print('The predicted rainfall for the year 2021 in ' + St[i]+ ' using moving average is: %0.2f' %(In_pre[si-1]))
    Y2=exp_smoothing_extn(X,Y,2021,alpha)
    print(('The predicted rainfall for the year 2021 in ' + St[i]+ ' using exponential average is: %0.2f' %(Y2[-1])))
    print('\n')

    #Plotting the curves
    L2=[i for i in range(2016,2022)]
    L2=np.array(L2)
    X1=np.concatenate((X,L2))
    Y1=np.concatenate((mean,In_pre))
    plt.plot(X,Y,label='Actual data')
    plt.plot(X1,Y2,label="exp_alpha=%f" %alpha)
    plt.plot(X1,Y1,label='Rolling Mean')
    plt.xlabel('YEAR')
    plt.ylabel('ANNUAL RAINFALL')
    plt.title(St[i])
    plt.legend()
    plt.show()
# Out:
# Training set error for moving average ANDAMAN & NICOBAR ISLANDS  400.986434
# Training set error for exponential smothing ANDAMAN & NICOBAR ISLANDS  529.553885
# The predicted rainfall for the year 2021 in ANDAMAN & NICOBAR ISLANDS using moving average is: 2927.44
# The predicted rainfall for the year 2021 in ANDAMAN & NICOBAR ISLANDS using exponential average is: 2228.67
# Training set error for moving average ARUNACHAL PRADESH  1056.106071
# Training set error for exponential smothing ARUNACHAL PRADESH  888.187896
# The predicted rainfall for the year 2021 in ARUNACHAL PRADESH using moving average is: 3418.86
# The predicted rainfall for the year 2021 in ARUNACHAL PRADESH using exponential average is: 2141.92
# Training set error for moving average ASSAM & MEGHALAYA  304.602893
# Training set error for exponential smothing ASSAM & MEGHALAYA  405.598412
# The predicted rainfall for the year 2021 in ASSAM & MEGHALAYA using moving average is: 2580.70
# The predicted rainfall for the year 2021 in ASSAM & MEGHALAYA using exponential average is: 2061.66
# Training set error for moving average NAGA MANI MIZO TRIPURA  425.836763
# Training set error for exponential smothing NAGA MANI MIZO TRIPURA  422.830967
# The predicted rainfall for the year 2021 in NAGA MANI MIZO TRIPURA using moving average is: 2433.62
# The predicted rainfall for the year 2021 in NAGA MANI MIZO TRIPURA using exponential average is: 1957.65
# Training set error for moving average SUB HIMALAYAN WEST BENGAL & SIKKIM  327.108311
# Training set error for exponential smothing SUB HIMALAYAN WEST BENGAL & SIKKIM  456.907886
# The predicted rainfall for the year 2021 in SUB HIMALAYAN WEST BENGAL & SIKKIM using moving average is: 2752.22
# The predicted rainfall for the year 2021 in SUB HIMALAYAN WEST BENGAL & SIKKIM using exponential average is: 2116.08
# Training set error for moving average GANGETIC WEST BENGAL  225.736089
# Training set error for exponential smothing GANGETIC WEST BENGAL  308.975463
# The predicted rainfall for the year 2021 in GANGETIC WEST BENGAL using moving average is: 1490.49
# The predicted rainfall for the year 2021 in GANGETIC WEST BENGAL using exponential average is: 1860.01
# Training set error for moving average ORISSA  183.939206
# Training set error for exponential smothing ORISSA  262.359935
# The predicted rainfall for the year 2021 in ORISSA using moving average is: 1458.17
# The predicted rainfall for the year 2021 in ORISSA using exponential average is: 1836.84
# Training set error for moving average JHARKHAND  194.907027
# Training set error for exponential smothing JHARKHAND  276.209000
# The predicted rainfall for the year 2021 in JHARKHAND using moving average is: 1309.30
# The predicted rainfall for the year 2021 in JHARKHAND using exponential average is: 1537.62
# Training set error for moving average BIHAR  190.056815
# Training set error for exponential smothing BIHAR  249.219501
# The predicted rainfall for the year 2021 in BIHAR using moving average is: 1197.63
# The predicted rainfall for the year 2021 in BIHAR using exponential average is: 1349.75
# Training set error for moving average EAST UTTAR PRADESH  199.608431
# Training set error for exponential smothing EAST UTTAR PRADESH  249.993603
# The predicted rainfall for the year 2021 in EAST UTTAR PRADESH using moving average is: 979.21
# The predicted rainfall for the year 2021 in EAST UTTAR PRADESH using exponential average is: 954.07
# Training set error for moving average WEST UTTAR PRADESH  185.707379
# Training set error for exponential smothing WEST UTTAR PRADESH  278.012108
# The predicted rainfall for the year 2021 in WEST UTTAR PRADESH using moving average is: 827.11
# The predicted rainfall for the year 2021 in WEST UTTAR PRADESH using exponential average is: 780.92
# Training set error for moving average UTTARAKHAND  258.837249
# Training set error for exponential smothing UTTARAKHAND  340.682059
# The predicted rainfall for the year 2021 in UTTARAKHAND using moving average is: 1465.70
# The predicted rainfall for the year 2021 in UTTARAKHAND using exponential average is: 1865.46
# Training set error for moving average HARYANA DELHI & CHANDIGARH  139.197110
# Training set error for exponential smothing HARYANA DELHI & CHANDIGARH  200.122515
# The predicted rainfall for the year 2021 in HARYANA DELHI & CHANDIGARH using moving average is: 530.50
# The predicted rainfall for the year 2021 in HARYANA DELHI & CHANDIGARH using exponential average is: 421.84
# Training set error for moving average PUNJAB  160.068028
# Training set error for exponential smothing PUNJAB  230.899212
# The predicted rainfall for the year 2021 in PUNJAB using moving average is: 593.54
# The predicted rainfall for the year 2021 in PUNJAB using exponential average is: 493.80
# Training set error for moving average HIMACHAL PRADESH  241.901295
# Training set error for exponential smothing HIMACHAL PRADESH  268.715912
# The predicted rainfall for the year 2021 in HIMACHAL PRADESH using moving average is: 1260.35
# The predicted rainfall for the year 2021 in HIMACHAL PRADESH using exponential average is: 1410.82
# Training set error for moving average JAMMU & KASHMIR  230.364949
# Training set error for exponential smothing JAMMU & KASHMIR  278.641266
# The predicted rainfall for the year 2021 in JAMMU & KASHMIR using moving average is: 1139.68
# The predicted rainfall for the year 2021 in JAMMU & KASHMIR using exponential average is: 1418.50
# Training set error for moving average WEST RAJASTHAN  105.919072
# Training set error for exponential smothing WEST RAJASTHAN  151.300745
# The predicted rainfall for the year 2021 in WEST RAJASTHAN using moving average is: 292.67
# The predicted rainfall for the year 2021 in WEST RAJASTHAN using exponential average is: 418.95
# Training set error for moving average EAST RAJASTHAN  162.003330
# Training set error for exponential smothing EAST RAJASTHAN  231.239742
# The predicted rainfall for the year 2021 in EAST RAJASTHAN using moving average is: 655.22
# The predicted rainfall for the year 2021 in EAST RAJASTHAN using exponential average is: 859.32
# Training set error for moving average WEST MADHYA PRADESH  179.318318
# Training set error for exponential smothing WEST MADHYA PRADESH  253.143703
# The predicted rainfall for the year 2021 in WEST MADHYA PRADESH using moving average is: 944.36
# The predicted rainfall for the year 2021 in WEST MADHYA PRADESH using exponential average is: 1086.34
# Training set error for moving average EAST MADHYA PRADESH  214.849291
# Training set error for exponential smothing EAST MADHYA PRADESH  308.654929
# The predicted rainfall for the year 2021 in EAST MADHYA PRADESH using moving average is: 1205.00
# The predicted rainfall for the year 2021 in EAST MADHYA PRADESH using exponential average is: 1408.36
# Training set error for moving average GUJARAT REGION  272.770561
# Training set error for exponential smothing GUJARAT REGION  379.223750
# The predicted rainfall for the year 2021 in GUJARAT REGION using moving average is: 918.23
# The predicted rainfall for the year 2021 in GUJARAT REGION using exponential average is: 1228.50
# Training set error for moving average SAURASHTRA & KUTCH  197.726647
# Training set error for exponential smothing SAURASHTRA & KUTCH  279.019595
# The predicted rainfall for the year 2021 in SAURASHTRA & KUTCH using moving average is: 495.16
# The predicted rainfall for the year 2021 in SAURASHTRA & KUTCH using exponential average is: 599.41
# Training set error for moving average KONKAN & GOA  475.032173
# Training set error for exponential smothing KONKAN & GOA  569.788548
# The predicted rainfall for the year 2021 in KONKAN & GOA using moving average is: 2977.69
# The predicted rainfall for the year 2021 in KONKAN & GOA using exponential average is: 2275.68
# Training set error for moving average MADHYA MAHARASHTRA  155.972049
# Training set error for exponential smothing MADHYA MAHARASHTRA  178.151275
# The predicted rainfall for the year 2021 in MADHYA MAHARASHTRA using moving average is: 880.23
# The predicted rainfall for the year 2021 in MADHYA MAHARASHTRA using exponential average is: 918.17
# Training set error for moving average MATATHWADA  184.572999
# Training set error for exponential smothing MATATHWADA  240.933315
# The predicted rainfall for the year 2021 in MATATHWADA using moving average is: 790.69
# The predicted rainfall for the year 2021 in MATATHWADA using exponential average is: 742.65
# Training set error for moving average VIDARBHA  198.662220
# Training set error for exponential smothing VIDARBHA  300.498117
# The predicted rainfall for the year 2021 in VIDARBHA using moving average is: 1095.46
# The predicted rainfall for the year 2021 in VIDARBHA using exponential average is: 1305.47
# Training set error for moving average CHHATTISGARH  205.953825
# Training set error for exponential smothing CHHATTISGARH  288.886380
# The predicted rainfall for the year 2021 in CHHATTISGARH using moving average is: 1371.73
# The predicted rainfall for the year 2021 in CHHATTISGARH using exponential average is: 1691.25
# Training set error for moving average COASTAL ANDHRA PRADESH  186.170271
# Training set error for exponential smothing COASTAL ANDHRA PRADESH  270.138669
# The predicted rainfall for the year 2021 in COASTAL ANDHRA PRADESH using moving average is: 1052.90
# The predicted rainfall for the year 2021 in COASTAL ANDHRA PRADESH using exponential average is: 1159.06
# Training set error for moving average TELANGANA  200.406220
# Training set error for exponential smothing TELANGANA  302.790172
# The predicted rainfall for the year 2021 in TELANGANA using moving average is: 953.38
# The predicted rainfall for the year 2021 in TELANGANA using exponential average is: 1130.06
# Training set error for moving average RAYALSEEMA  145.842515
# Training set error for exponential smothing RAYALSEEMA  222.877329
# The predicted rainfall for the year 2021 in RAYALSEEMA using moving average is: 766.21
# The predicted rainfall for the year 2021 in RAYALSEEMA using exponential average is: 745.16
# Training set error for moving average TAMIL NADU  162.638245
# Training set error for exponential smothing TAMIL NADU  200.841911
# The predicted rainfall for the year 2021 in TAMIL NADU using moving average is: 943.71
# The predicted rainfall for the year 2021 in TAMIL NADU using exponential average is: 1058.73
# Training set error for moving average COASTAL KARNATAKA  473.312674
# Training set error for exponential smothing COASTAL KARNATAKA  599.578062
# The predicted rainfall for the year 2021 in COASTAL KARNATAKA using moving average is: 3408.41
# The predicted rainfall for the year 2021 in COASTAL KARNATAKA using exponential average is: 2947.74
# Training set error for moving average NORTH INTERIOR KARNATAKA  130.878688
# Training set error for exponential smothing NORTH INTERIOR KARNATAKA  167.608739
# The predicted rainfall for the year 2021 in NORTH INTERIOR KARNATAKA using moving average is: 717.80
# The predicted rainfall for the year 2021 in NORTH INTERIOR KARNATAKA using exponential average is: 842.48
# Training set error for moving average SOUTH INTERIOR KARNATAKA  147.312454
# Training set error for exponential smothing SOUTH INTERIOR KARNATAKA  200.399262
# The predicted rainfall for the year 2021 in SOUTH INTERIOR KARNATAKA using moving average is: 1040.39
# The predicted rainfall for the year 2021 in SOUTH INTERIOR KARNATAKA using exponential average is: 1294.17
# Training set error for moving average KERALA  414.402624
# Training set error for exponential smothing KERALA  508.615176
# The predicted rainfall for the year 2021 in KERALA using moving average is: 2925.49
# The predicted rainfall for the year 2021 in KERALA using exponential average is: 2406.31
# Training set error for moving average LAKSHADWEEP  261.192654
# Training set error for exponential smothing LAKSHADWEEP  340.846740
# The predicted rainfall for the year 2021 in LAKSHADWEEP using moving average is: 1590.89
# The predicted rainfall for the year 2021 in LAKSHADWEEP using exponential average is: 1981.58
